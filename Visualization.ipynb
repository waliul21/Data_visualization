# %% [markdown]
# <a href="https://colab.research.google.com/github/waliul21/Data_visualization/blob/main/Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
csv = pd.read_csv('/content/drive/MyDrive/DMLab/bank.csv')
csv.head()
# Out:
#    age         job  marital  education  ... pdays  previous poutcome deposit
# 0   59      admin.  married  secondary  ...    -1         0  unknown     yes
# 1   56      admin.  married  secondary  ...    -1         0  unknown     yes
# 2   41  technician  married  secondary  ...    -1         0  unknown     yes
# 3   55    services  married  secondary  ...    -1         0  unknown     yes
# 4   54      admin.  married   tertiary  ...    -1         0  unknown     yes
#
# [5 rows x 17 columns]

# %%
print("Job graph visual")
sb.set_style("whitegrid")
plt.figure(figsize=(14,7))
sb.countplot(csv['job'])
plt.show()
# Out:
# Job graph visual
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
import csv
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sb
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
print("Marital graph visual")
sb.set_style("whitegrid")
plt.figure(figsize=(14,7))
sb.countplot(csv['marital'])
plt.show()
# Out:
# Marital graph visual
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
print("Education graph visual")
sb.set_style("whitegrid")
plt.figure(figsize=(14,7))
sb.countplot(csv['education'])
plt.show()
# Out:
# Education graph visual
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
print("Loan graph visual")
sb.set_style("whitegrid")
plt.figure(figsize=(14,7))
sb.countplot(csv['loan'])
plt.show()
# Out:
# Loan graph visual
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
print("Contact graph visual")
sb.set_style("whitegrid")
plt.figure(figsize=(14,7))
sb.countplot(csv['contact'])
plt.show()
# Out:
# Contact graph visual
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
print("Deposit graph visual")
sb.set_style("whitegrid")
plt.figure(figsize=(14,7))
sb.countplot(csv['deposit'])
plt.show()
# Out:
# Deposit graph visual
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
print("Correlation graph visual")
plt.figure(figsize=(14,7))
cor = csv.corr()
sb.heatmap(cor,annot=True)
plt.show()
# Out:
# Correlation graph visual

# %%
print("Age graph visual")
plt.plot(csv.age.values)
plt.show()
# Out:
# Age graph visual

# %%
print("Age graph visual")
plt.hist(csv.age.values)
plt.show()
# Out:
# Age graph visual
